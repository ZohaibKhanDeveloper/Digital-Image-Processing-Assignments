# %%
import cv2
import numpy as np

# %%
img = cv2.imread('Panda.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
for cnt in contours:
    area = cv2.contourArea(cnt)
    if area > 100:
        print(f"Object Area: {area} pixels")
        cv2.drawContours(img, [cnt], -1, (0, 0, 255), 5)
        M = cv2.moments(cnt)
        if M["m00"] != 0:
            cx = int(M["m10"] / M["m00"])
            cy = int(M["m01"] / M["m00"])
            cv2.putText(img, str(int(area)), (cx, cy), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
cv2.imshow('Calculated Areas', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Object Area: 219.5 pixels
# Object Area: 7808.5 pixels
# Object Area: 4341.5 pixels
